# %% [markdown]
# # Columbia Attention Token - Token Scoring System

# %% [markdown]
# ## About This Notebook...
#
# This notebook begins by importing the .csv file containing the cleaned Slack data from the 'slack_eda_and_wrangling' notebook. After creating a DataFrame from the file and reiewing it, the groupby() function is applied to get an idea of total counts that represent cumulative participation. Considering these counts, two columns are added, both constructed from simple equations that give a better breakdown of engagement. The first is the user's "reply ratio," which takes the sum of the replies to a user's posts and divides that by the number of user's responsible for those replies. The next is a "token score," which uses the reply ratio as one of its variables, along with the sum of the text length of each user's posts, the sum of reactions each user contributed, and the sum of attachments each user provided in posts, all of which have been given a unique weighting. The result is the each user's unique "token score," which is used for the distribution of coins minted in our smart contracts.

# %% [markdown]
# #### Imports and DataFrame Review

# %%
# Imports
import pandas as pd
import numpy as np
from pathlib import Path
import csv

# %%
# Import the csv file contained cleaned slack channel data
slack_csv_path = Path("./slack_cleaned.csv")
slack_df = pd.read_csv(slack_csv_path)
slack_df.head(20)
# Out:
#    channel_name         user  \
# 0       fintech  U023R27V74N
# 1       fintech  U023R27V74N
# 2       fintech  U023R27V74N
# 3       fintech  U025DPVSGBT
# 4       fintech  U024R294XHV
# 5       fintech  U025DPVSGBT
# 6       fintech  U023R27V74N
# 7       fintech  U023R27V74N
# 8       fintech  U023R27V74N
# 9       fintech  U023R27V74N
# 10      fintech  U024R294XHV
# 11      fintech  U024R294XHV
# 12      fintech  U025DPVSGBT
# 13      fintech  U024R294XHV
# 14      fintech  U024R294XHV
# 15      fintech  U024R294XHV
# 16      fintech  U024R294XHV
# 17      fintech  U024R294XHV
# 18      fintech  U024R294XHV
# 19      fintech  U025E9FJVNU
#
#                                                  text  text_length  \
# 0   two upcoming conferences:\n• finovatefall sept...          415
# 1   also two free virtual expos sept 29-30:\n• blo...          168
# 2   the columbia center of ai is having a symposiu...          170
# 3   Y’all, free diy NFT class kicking off at 12pm ...          120
# 4   Anyone interested in next generation APIs here...          206
# 5   <https://medium.com/derivadex/what-are-perpetu...          208
# 6   <https://www.fastcompany.com/90669744/spotify-...           66
# 7   if you are interested in learning how azure su...          644
# 8   Fintech Junction Summer Event\nThere is a free...          107
# 9   MoneyNext Open Banking Summit June 22-23\nIf y...          159
# 10  Been following this company for a bit of a whi...          777
# 11  If anyone is interested in joining their teleg...           70
# 12                                   I am interested!           16
# 13  Couple of things I want to mention about stell...          501
# 14                              I’ll send you a link            21
# 15  <https://t.me/quantumstellar|https://t.me/quan...           57
# 16  Claims are being made that quantum computing i...          128
# 17  Here’s their mother website <https://www.class...           75
# 18  ETH competitors \n\n<https://ethex-smm.medium....          229
# 19  I could use a Fintech Career Strategist. Anyon...           76
#
#     reply_count  reply_users_count  replies_true   day_name day_type  time  \
# 0             0                  0         False   Thursday  Weekday     1
# 1             0                  0         False   Thursday  Weekday     1
# 2             0                  0         False   Thursday  Weekday    18
# 3             0                  0         False     Sunday  Weekend    15
# 4             0                  0         False  Wednesday  Weekday    12
# 5             0                  0         False   Thursday  Weekday    14
# 6             0                  0         False     Monday  Weekday    16
# 7             0                  0         False     Monday  Weekday    22
# 8             0                  0         False    Tuesday  Weekday    16
# 9             0                  0         False     Friday  Weekday    19
# 10            7                  2          True   Thursday  Weekday    17
# 11            0                  0         False   Thursday  Weekday    17
# 12            0                  0         False   Thursday  Weekday    17
# 13            0                  0         False   Thursday  Weekday    17
# 14            0                  0         False   Thursday  Weekday    17
# 15            0                  0         False   Thursday  Weekday    17
# 16            0                  0         False   Thursday  Weekday    17
# 17            0                  0         False   Thursday  Weekday    17
# 18            0                  0         False   Thursday  Weekday    23
# 19            2                  1          True   Thursday  Weekday    16
#
#       dayparts  day_number      month  reactions_count    reactions_name  \
# 0   Late Night          12     August                0                 0
# 1   Late Night          12     August                0                 0
# 2      Evening          30  September                1            muscle
# 3    Afternoon          26  September                3                +1
# 4    Afternoon           6    October                2              fire
# 5    Afternoon           7    October                1      orange_heart
# 6      Evening          30     August                0                 0
# 7        Night          11    October                0                 0
# 8      Evening          22       June                2                +1
# 9      Evening          18       June                6                +1
# 10     Evening          21    October                1              eyes
# 11     Evening          21    October                0                 0
# 12     Evening          21    October                0                 0
# 13     Evening          21    October                0                 0
# 14     Evening          21    October                0                 0
# 15     Evening          21    October                0                 0
# 16     Evening          21    October                0                 0
# 17     Evening          21    October                0                 0
# 18       Night          21    October                1             heart
# 19     Evening          29       July                1  white_check_mark
#
#                                           attachments  attachments_true  \
# 0            https://informaconnect.com/finovatefall/              True
# 1           https://blockchain-expo.com/northamerica/              True
# 2   https://www.eventbrite.com/e/cait-inaugural-sy...              True
# 3                    https://buildspace.so/build-nfts              True
# 4               https://www.sigtech.com/platform/data              True
# 5   https://medium.com/derivadex/what-are-perpetua...              True
# 6   https://www.fastcompany.com/90669744/spotify-t...              True
# 7   https://info.microsoft.com/ww-landing-use-ai-t...              True
# 8                                                None              True
# 9           https://moneynext.tv/open-banking-summit/              True
# 10  https://quantum-stellar.io/Stellar%20-%20About...              True
# 11                                               None              True
# 12                                               None              True
# 13                                               None              True
# 14                                               None              True
# 15                        https://t.me/quantumstellar              True
# 16                                               None              True
# 17                             https://www.classiq.io              True
# 18  https://ethex-smm.medium.com/top-5-altcoins-to...              True
# 19                                               None              True
#
#     reaction_true
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# 5            True
# 6            True
# 7            True
# 8            True
# 9            True
# 10           True
# 11           True
# 12           True
# 13           True
# 14           True
# 15           True
# 16           True
# 17           True
# 18           True
# 19           True

# %% [markdown]
# #### Assessing Counts for Scoring

# %%
#print(slack_df.groupby(["user"])[['real_name']])
new_df = slack_df.groupby(["user"])[["text_length"]].sum()
print(new_df)
#by_month_df = slack_df.groupby(['user', 'real_name'])
#by_month_df.head(35)
# Out:
#              text_length
# user
# U023F2P1CKZ         1822
# U023QT9923G         6485
# U023R27V74N        24585
# U023TR6SGJZ        12933
# U024GNF18MB           73
# U024GNX9CGM        12825
# U024J4FLHHD         9278
# U024J6725K8         1936
# U024JN413AR          853
# U024MNS46GM          443
# U024QHZRR6E          387
# U024R294XHV        11657
# U024SCVTY5T          954
# U024VFELUBZ         1014
# U024VKV1V6K         1086
# U024WBY5S5Q         3871
# U024WMKUP0C          578
# U024YNXFLUR          117
# U024ZA73WKV          106
# U02507X9M5G         1276
# U02536C3K3P          601
# U0253G8HJ0H          297
# U0253QXQT2S         1746
# U0253RQ4Q5U         1735
# U02548Z2S69         2600
# U0254U087B7         1711
# U0255KNQ0N8          206
# U0256T3ARB6           52
# U0259QYTM1N          210
# U025AJNRNN6         2344
# U025AK2MCCA          432
# U025DPVSGBT         5654
# U025E9FJVNU         2195
# U025G8XUG8L          217
# U025GLTLJBE          627
# U025JC6MEBY          507
# U025M2H7U65            9
# U025NEBV4C9          341
# U025VP9A3UG          372
# U0260MXFCV9        15078
# U026QCRFCDN          148
# U0275C12GCD          169
# U027C0P4D7V          134
# U02DML4ACDU           77
# U02LRJS6UR4          393
# USLACKBOT             25

# %%
# Drop the columns that aren't needed
feat_slack_df = slack_df.drop(['text', 'day_name', 'day_type', 'time', 'dayparts', 'day_number', 'month', 'reaction_true'], axis=1)

feat_slack_df.head(20)
# Out:
#    channel_name         user  text_length  reply_count  reply_users_count  \
# 0       fintech  U023R27V74N          415            0                  0
# 1       fintech  U023R27V74N          168            0                  0
# 2       fintech  U023R27V74N          170            0                  0
# 3       fintech  U025DPVSGBT          120            0                  0
# 4       fintech  U024R294XHV          206            0                  0
# 5       fintech  U025DPVSGBT          208            0                  0
# 6       fintech  U023R27V74N           66            0                  0
# 7       fintech  U023R27V74N          644            0                  0
# 8       fintech  U023R27V74N          107            0                  0
# 9       fintech  U023R27V74N          159            0                  0
# 10      fintech  U024R294XHV          777            7                  2
# 11      fintech  U024R294XHV           70            0                  0
# 12      fintech  U025DPVSGBT           16            0                  0
# 13      fintech  U024R294XHV          501            0                  0
# 14      fintech  U024R294XHV           21            0                  0
# 15      fintech  U024R294XHV           57            0                  0
# 16      fintech  U024R294XHV          128            0                  0
# 17      fintech  U024R294XHV           75            0                  0
# 18      fintech  U024R294XHV          229            0                  0
# 19      fintech  U025E9FJVNU           76            2                  1
#
#     replies_true  reactions_count    reactions_name  \
# 0          False                0                 0
# 1          False                0                 0
# 2          False                1            muscle
# 3          False                3                +1
# 4          False                2              fire
# 5          False                1      orange_heart
# 6          False                0                 0
# 7          False                0                 0
# 8          False                2                +1
# 9          False                6                +1
# 10          True                1              eyes
# 11         False                0                 0
# 12         False                0                 0
# 13         False                0                 0
# 14         False                0                 0
# 15         False                0                 0
# 16         False                0                 0
# 17         False                0                 0
# 18         False                1             heart
# 19          True                1  white_check_mark
#
#                                           attachments  attachments_true
# 0            https://informaconnect.com/finovatefall/              True
# 1           https://blockchain-expo.com/northamerica/              True
# 2   https://www.eventbrite.com/e/cait-inaugural-sy...              True
# 3                    https://buildspace.so/build-nfts              True
# 4               https://www.sigtech.com/platform/data              True
# 5   https://medium.com/derivadex/what-are-perpetua...              True
# 6   https://www.fastcompany.com/90669744/spotify-t...              True
# 7   https://info.microsoft.com/ww-landing-use-ai-t...              True
# 8                                                None              True
# 9           https://moneynext.tv/open-banking-summit/              True
# 10  https://quantum-stellar.io/Stellar%20-%20About...              True
# 11                                               None              True
# 12                                               None              True
# 13                                               None              True
# 14                                               None              True
# 15                        https://t.me/quantumstellar              True
# 16                                               None              True
# 17                             https://www.classiq.io              True
# 18  https://ethex-smm.medium.com/top-5-altcoins-to...              True
# 19                                               None              True

# %%
# Group the slack data by the User ID and create a new DataFrame from this action,
# then calculate the sum of the columns to get a count of the user's total interactions.

grouped_slack_df = feat_slack_df.groupby('user').sum()

grouped_slack_df
# Out:
#              text_length  reply_count  reply_users_count  replies_true  \
# user
# U023F2P1CKZ         1822           88                 62             5
# U023QT9923G         6485            2                  2             2
# U023R27V74N        24585           13                 11             5
# U023TR6SGJZ        12933            7                  4             2
# U024GNF18MB           73            0                  0             0
# U024GNX9CGM        12825          103                 66            32
# U024J4FLHHD         9278            3                  3             2
# U024J6725K8         1936           18                  5             3
# U024JN413AR          853           16                 15             8
# U024MNS46GM          443            3                  2             2
# U024QHZRR6E          387            0                  0             0
# U024R294XHV        11657           97                 62            31
# U024SCVTY5T          954           13                 11             6
# U024VFELUBZ         1014           36                 22             8
# U024VKV1V6K         1086            2                  2             1
# U024WBY5S5Q         3871           39                 25            14
# U024WMKUP0C          578            1                  1             1
# U024YNXFLUR          117            0                  0             0
# U024ZA73WKV          106            3                  3             2
# U02507X9M5G         1276           29                  5             2
# U02536C3K3P          601            5                  4             3
# U0253G8HJ0H          297            2                  2             1
# U0253QXQT2S         1746            9                  6             3
# U0253RQ4Q5U         1735           22                 14             7
# U02548Z2S69         2600           15                 10             5
# U0254U087B7         1711           18                 10             5
# U0255KNQ0N8          206            0                  0             0
# U0256T3ARB6           52            0                  0             0
# U0259QYTM1N          210            2                  2             1
# U025AJNRNN6         2344           35                 11             6
# U025AK2MCCA          432            3                  3             2
# U025DPVSGBT         5654           22                 17             9
# U025E9FJVNU         2195           25                 16            11
# U025G8XUG8L          217            0                  0             0
# U025GLTLJBE          627            8                  7             3
# U025JC6MEBY          507            0                  0             0
# U025M2H7U65            9            0                  0             0
# U025NEBV4C9          341            4                  4             1
# U025VP9A3UG          372            1                  1             1
# U0260MXFCV9        15078            4                  4             3
# U026QCRFCDN          148            0                  0             0
# U0275C12GCD          169            0                  0             0
# U027C0P4D7V          134            0                  0             0
# U02DML4ACDU           77            0                  0             0
# U02LRJS6UR4          393            0                  0             0
# USLACKBOT             25            3                  3             1
#
#              reactions_count  attachments_true
# user
# U023F2P1CKZ               28                23
# U023QT9923G               10                66
# U023R27V74N               45               164
# U023TR6SGJZ               21                52
# U024GNF18MB                1                 2
# U024GNX9CGM               39               101
# U024J4FLHHD               18                64
# U024J6725K8               10                35
# U024JN413AR                8                15
# U024MNS46GM                2                12
# U024QHZRR6E                2                 8
# U024R294XHV               50               128
# U024SCVTY5T                6                19
# U024VFELUBZ               10                19
# U024VKV1V6K                3                10
# U024WBY5S5Q               15                37
# U024WMKUP0C                5                11
# U024YNXFLUR                0                 3
# U024ZA73WKV                3                 5
# U02507X9M5G                4                21
# U02536C3K3P                2                11
# U0253G8HJ0H                2                 4
# U0253QXQT2S                7                15
# U0253RQ4Q5U                9                19
# U02548Z2S69               13                35
# U0254U087B7                3                19
# U0255KNQ0N8                0                 1
# U0256T3ARB6                0                 3
# U0259QYTM1N                1                 6
# U025AJNRNN6                9                39
# U025AK2MCCA                2                 3
# U025DPVSGBT               35                68
# U025E9FJVNU               23                28
# U025G8XUG8L                2                 4
# U025GLTLJBE                8                13
# U025JC6MEBY                0                 5
# U025M2H7U65                0                 1
# U025NEBV4C9                1                 4
# U025VP9A3UG                1                 6
# U0260MXFCV9               15               124
# U026QCRFCDN                0                 2
# U0275C12GCD                7                 4
# U027C0P4D7V                0                 1
# U02DML4ACDU                0                 1
# U02LRJS6UR4                1                 1
# USLACKBOT                  0                 1

# %% [markdown]
# #### Remember:
# - the 'text_length' column represents the total number of characters written in all posts by each user.
# - the 'reply_count' column represents the total number of replies each user has gotten on their posts.
# - the 'reply_users_count' column represents the total number of other users who replied to a user's posts.
# - the 'attachments_true' column is a summed boolean representing the total number of times a post contained an attachment.
# - the 'reactions_count' column represents the total number of reactions each user contributed.

# %% [markdown]
# #### Token Scoring System:
# - each character the user has written is worth 2 points.
# - each attachment a user has contributed is worth 20 points.
# - the user's "reply ratio" is multiplied by 200 points.
# - each reaction a user has contributed is worth 5 points.

# %%
# Check the data types of the columns

grouped_slack_df.dtypes
# Out:
# text_length          int64
# reply_count          int64
# reply_users_count    int64
# replies_true         int64
# reactions_count      int64
# attachments_true     int64
# dtype: object

# %% [markdown]
# ### Creating New Columns for Reply Ratio and Token Score

# %%
# Create a reply ratio column
grouped_slack_df['reply_ratio'] = grouped_slack_df['reply_count'] / grouped_slack_df['reply_users_count']

# Review DataFrame for new column
grouped_slack_df.head(15)
# Out:
#              text_length  reply_count  reply_users_count  replies_true  \
# user
# U023F2P1CKZ         1822           88                 62             5
# U023QT9923G         6485            2                  2             2
# U023R27V74N        24585           13                 11             5
# U023TR6SGJZ        12933            7                  4             2
# U024GNF18MB           73            0                  0             0
# U024GNX9CGM        12825          103                 66            32
# U024J4FLHHD         9278            3                  3             2
# U024J6725K8         1936           18                  5             3
# U024JN413AR          853           16                 15             8
# U024MNS46GM          443            3                  2             2
# U024QHZRR6E          387            0                  0             0
# U024R294XHV        11657           97                 62            31
# U024SCVTY5T          954           13                 11             6
# U024VFELUBZ         1014           36                 22             8
# U024VKV1V6K         1086            2                  2             1
#
#              reactions_count  attachments_true  reply_ratio
# user
# U023F2P1CKZ               28                23     1.419355
# U023QT9923G               10                66     1.000000
# U023R27V74N               45               164     1.181818
# U023TR6SGJZ               21                52     1.750000
# U024GNF18MB                1                 2          NaN
# U024GNX9CGM               39               101     1.560606
# U024J4FLHHD               18                64     1.000000
# U024J6725K8               10                35     3.600000
# U024JN413AR                8                15     1.066667
# U024MNS46GM                2                12     1.500000
# U024QHZRR6E                2                 8          NaN
# U024R294XHV               50               128     1.564516
# U024SCVTY5T                6                19     1.181818
# U024VFELUBZ               10                19     1.636364
# U024VKV1V6K                3                10     1.000000

# %%
# Drop NaN rows in the reply_ratio column
grouped_slack_df['reply_ratio'] = grouped_slack_df['reply_ratio'].fillna(0)

# %%
# Use the grouped data to write the conditional statements that will construct the point system for the eventual token distribution.

grouped_slack_df['token_score'] = ((2 * grouped_slack_df['text_length']) + (20 * grouped_slack_df['attachments_true'])
                                   + (200 * grouped_slack_df['reply_ratio']) + (5 * grouped_slack_df['reactions_count']))

# Review DataFrame for new column
grouped_slack_df
# Out:
#              text_length  reply_count  reply_users_count  replies_true  \
# user
# U023F2P1CKZ         1822           88                 62             5
# U023QT9923G         6485            2                  2             2
# U023R27V74N        24585           13                 11             5
# U023TR6SGJZ        12933            7                  4             2
# U024GNF18MB           73            0                  0             0
# U024GNX9CGM        12825          103                 66            32
# U024J4FLHHD         9278            3                  3             2
# U024J6725K8         1936           18                  5             3
# U024JN413AR          853           16                 15             8
# U024MNS46GM          443            3                  2             2
# U024QHZRR6E          387            0                  0             0
# U024R294XHV        11657           97                 62            31
# U024SCVTY5T          954           13                 11             6
# U024VFELUBZ         1014           36                 22             8
# U024VKV1V6K         1086            2                  2             1
# U024WBY5S5Q         3871           39                 25            14
# U024WMKUP0C          578            1                  1             1
# U024YNXFLUR          117            0                  0             0
# U024ZA73WKV          106            3                  3             2
# U02507X9M5G         1276           29                  5             2
# U02536C3K3P          601            5                  4             3
# U0253G8HJ0H          297            2                  2             1
# U0253QXQT2S         1746            9                  6             3
# U0253RQ4Q5U         1735           22                 14             7
# U02548Z2S69         2600           15                 10             5
# U0254U087B7         1711           18                 10             5
# U0255KNQ0N8          206            0                  0             0
# U0256T3ARB6           52            0                  0             0
# U0259QYTM1N          210            2                  2             1
# U025AJNRNN6         2344           35                 11             6
# U025AK2MCCA          432            3                  3             2
# U025DPVSGBT         5654           22                 17             9
# U025E9FJVNU         2195           25                 16            11
# U025G8XUG8L          217            0                  0             0
# U025GLTLJBE          627            8                  7             3
# U025JC6MEBY          507            0                  0             0
# U025M2H7U65            9            0                  0             0
# U025NEBV4C9          341            4                  4             1
# U025VP9A3UG          372            1                  1             1
# U0260MXFCV9        15078            4                  4             3
# U026QCRFCDN          148            0                  0             0
# U0275C12GCD          169            0                  0             0
# U027C0P4D7V          134            0                  0             0
# U02DML4ACDU           77            0                  0             0
# U02LRJS6UR4          393            0                  0             0
# USLACKBOT             25            3                  3             1
#
#              reactions_count  attachments_true  reply_ratio   token_score
# user
# U023F2P1CKZ               28                23     1.419355   4527.870968
# U023QT9923G               10                66     1.000000  14540.000000
# U023R27V74N               45               164     1.181818  52911.363636
# U023TR6SGJZ               21                52     1.750000  27361.000000
# U024GNF18MB                1                 2     0.000000    191.000000
# U024GNX9CGM               39               101     1.560606  28177.121212
# U024J4FLHHD               18                64     1.000000  20126.000000
# U024J6725K8               10                35     3.600000   5342.000000
# U024JN413AR                8                15     1.066667   2259.333333
# U024MNS46GM                2                12     1.500000   1436.000000
# U024QHZRR6E                2                 8     0.000000    944.000000
# U024R294XHV               50               128     1.564516  26436.903226
# U024SCVTY5T                6                19     1.181818   2554.363636
# U024VFELUBZ               10                19     1.636364   2785.272727
# U024VKV1V6K                3                10     1.000000   2587.000000
# U024WBY5S5Q               15                37     1.560000   8869.000000
# U024WMKUP0C                5                11     1.000000   1601.000000
# U024YNXFLUR                0                 3     0.000000    294.000000
# U024ZA73WKV                3                 5     1.000000    527.000000
# U02507X9M5G                4                21     5.800000   4152.000000
# U02536C3K3P                2                11     1.250000   1682.000000
# U0253G8HJ0H                2                 4     1.000000    884.000000
# U0253QXQT2S                7                15     1.500000   4127.000000
# U0253RQ4Q5U                9                19     1.571429   4209.285714
# U02548Z2S69               13                35     1.500000   6265.000000
# U0254U087B7                3                19     1.800000   4177.000000
# U0255KNQ0N8                0                 1     0.000000    432.000000
# U0256T3ARB6                0                 3     0.000000    164.000000
# U0259QYTM1N                1                 6     1.000000    745.000000
# U025AJNRNN6                9                39     3.181818   6149.363636
# U025AK2MCCA                2                 3     1.000000   1134.000000
# U025DPVSGBT               35                68     1.294118  13101.823529
# U025E9FJVNU               23                28     1.562500   5377.500000
# U025G8XUG8L                2                 4     0.000000    524.000000
# U025GLTLJBE                8                13     1.142857   1782.571429
# U025JC6MEBY                0                 5     0.000000   1114.000000
# U025M2H7U65                0                 1     0.000000     38.000000
# U025NEBV4C9                1                 4     1.000000    967.000000
# U025VP9A3UG                1                 6     1.000000   1069.000000
# U0260MXFCV9               15               124     1.000000  32911.000000
# U026QCRFCDN                0                 2     0.000000    336.000000
# U0275C12GCD                7                 4     0.000000    453.000000
# U027C0P4D7V                0                 1     0.000000    288.000000
# U02DML4ACDU                0                 1     0.000000    174.000000
# U02LRJS6UR4                1                 1     0.000000    811.000000
# USLACKBOT                  0                 1     1.000000    270.000000

# %%
# Save to csv
grouped_slack_df.to_csv('tss_slack.csv', index=True)
