# %% [markdown]
# # Columbia Attention Token - EDA and Wrangling of Engagement Data from CU-FinTech Slack Channels

# %% [markdown]
# ## About This Notebook...
#
# This notebook contains code written for exploratory analysis and wrangling of data collected from the Slack communication channels of Columbia University FinTech program. The analayis began with the downloading and collection of raw data files in the .json format from Slack channels of interest (01-live-mw, 02-ask-the-class, 03-resources, and fintech) provided by the instructor. The Slack API is a good method for collecting this data, but without 'owner' or 'administrator' permissions, as a work-around, zip files previewed for sensitive information were requested. The raw data was parsed into folders according to the Slack channel of origin, then concatenated into a single DataFrame. With this step completed, assessment can begin. After assessment, some columns were slected to be dropped, as they did not pertain to the focus of the analysis. Once unnecessary columns are dropped, the process of cleaning the data begins. A series of cleaning functions were defined to carry out tasks such as filtering rows that have subtype values, datetime wrangling (which gives a breakdown of engagement traffic at various increments of time), extracting attchments and links, counting text length from posts and comments, and counting and identifying emojis used as reactions. The cleaning functions are then called and the cleaned DataFrame is reviewed. Once cleaning is accomplished, a function that carries out feature engineering is defined and called, giving us a cleaned and workable DataFrame for analysis of student, TA and instructor engagement with the Slack channels through the program's duration. The final step is to write this DataFrame into a .csv file for import into future notebooks.

# %% [markdown]
# ### Imports, initial DataFrame construction, and data assessment

# %%
# Imports
import os, json
import pandas as pd
import numpy as np
import glob
import csv
pd.options.mode.chained_assignment=None

# %% [markdown]
# #### Loading multiple JSON files into a single DataFrame

# %%
main_folder_path = './slack_channels_data'

def parse_all_json(main_folder_path):
    slack_df = pd.DataFrame()
    
    # Iterate through the group of folders
    for folder in os.listdir(main_folder_path):
        folder_path = os.path.join(main_folder_path, folder)
        
        if os.path.isdir(folder_path):
            # Iterate through each individual folder
            for file in os.listdir(folder_path):
                file = os.path.join(main_folder_path, folder, file)
            
            # Add a channel name column and indicate which folder the vlaue is coming from: 01_live, 02_ask_the_class, 03_resources, fintech
                if file.endswith('.json'):
                    slack_data = pd.read_json(file)
                    slack_data['channel_name'] = folder
                    slack_df = pd.concat([slack_df, slack_data])
                    
    return slack_df

slack_data = parse_all_json('./slack_channels_data/')

# %%
# Save to csv
slack_data.to_csv('slack_channels.csv', index=False)

# %% [markdown]
# #### Assessing the data

# %%
slack_data.shape
# Out:
# (1288, 34)

# %%
slack_data.head()
# Out:
#                           client_msg_id     type  \
# 0  5bf56972-c421-4d08-8f14-1af9a35e67eb  message
# 1  2f74859f-3d4b-4b0b-a666-aaa289787dae  message
# 0                                   NaN  message
# 1                                   NaN  message
# 2                                   NaN  message
#
#                                                 text         user  \
# 0  two upcoming conferences:\n• finovatefall sept...  U023R27V74N
# 1  also two free virtual expos sept 29-30:\n• blo...  U023R27V74N
# 0              <@U023TR6SGJZ> has joined the channel  U023TR6SGJZ
# 1              <@U023QT9923G> has joined the channel  U023QT9923G
# 2              <@U023R27V74N> has joined the channel  U023R27V74N
#
#              ts         team    user_team  source_team  \
# 0  1.628731e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 1  1.628733e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.622723e+09          NaN          NaN          NaN
# 1  1.622733e+09          NaN          NaN          NaN
# 2  1.622735e+09          NaN          NaN          NaN
#
#                                         user_profile  \
# 0  {'avatar_hash': '425d563aaa26', 'image_72': 'h...
# 1  {'avatar_hash': '425d563aaa26', 'image_72': 'h...
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#                                          attachments  ... subscribed  \
# 0  [{'title': 'FinovateFall fintech event', 'titl...  ...        NaN
# 1  [{'service_name': 'Blockchain Expo North Ameri...  ...        NaN
# 0                                                NaN  ...        NaN
# 1                                                NaN  ...        NaN
# 2                                                NaN  ...        NaN
#
#   parent_user_id edited purpose x_files hidden bot_id  bot_profile  old_name  \
# 0            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
# 1            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
# 0            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
# 1            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
# 2            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
#
#    name
# 0   NaN
# 1   NaN
# 0   NaN
# 1   NaN
# 2   NaN
#
# [5 rows x 34 columns]

# %%
# Reviewing column names
slack_data.columns
# Out:
# Index(['client_msg_id', 'type', 'text', 'user', 'ts', 'team', 'user_team',
#        'source_team', 'user_profile', 'attachments', 'blocks', 'channel_name',
#        'subtype', 'reactions', 'files', 'upload', 'display_as_bot',
#        'thread_ts', 'reply_count', 'reply_users_count', 'latest_reply',
#        'reply_users', 'replies', 'is_locked', 'subscribed', 'parent_user_id',
#        'edited', 'purpose', 'x_files', 'hidden', 'bot_id', 'bot_profile',
#        'old_name', 'name'],
#       dtype='object')

# %%
# Make a copy for a new DataFrame
slack_df = slack_data.copy()

# %%
# Review column names of new DataFrame for consistency
slack_df.columns
# Out:
# Index(['client_msg_id', 'type', 'text', 'user', 'ts', 'team', 'user_team',
#        'source_team', 'user_profile', 'attachments', 'blocks', 'channel_name',
#        'subtype', 'reactions', 'files', 'upload', 'display_as_bot',
#        'thread_ts', 'reply_count', 'reply_users_count', 'latest_reply',
#        'reply_users', 'replies', 'is_locked', 'subscribed', 'parent_user_id',
#        'edited', 'purpose', 'x_files', 'hidden', 'bot_id', 'bot_profile',
#        'old_name', 'name'],
#       dtype='object')

# %%
# Check how many values (posts, comments) each channel has
slack_df.channel_name.value_counts()
# Out:
# 02-ask-the-class    686
# 01-live-mw          439
# 03-resources        101
# fintech              62
# Name: channel_name, dtype: int64

# %%
# List of columns, their non-null objects and data type of columns
slack_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1288 entries, 0 to 1
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   client_msg_id      1112 non-null   object
#  1   type               1288 non-null   object
#  2   text               1288 non-null   object
#  3   user               1288 non-null   object
#  4   ts                 1288 non-null   float64
#  5   team               1082 non-null   object
#  6   user_team          1081 non-null   object
#  7   source_team        1081 non-null   object
#  8   user_profile       1081 non-null   object
#  9   attachments        130 non-null    object
#  10  blocks             1165 non-null   object
#  11  channel_name       1288 non-null   object
#  12  subtype            77 non-null     object
#  13  reactions          318 non-null    object
#  14  files              129 non-null    object
#  15  upload             129 non-null    object
#  16  display_as_bot     115 non-null    object
#  17  thread_ts          839 non-null    float64
#  18  reply_count        188 non-null    float64
#  19  reply_users_count  188 non-null    float64
#  20  latest_reply       188 non-null    float64
#  21  reply_users        188 non-null    object
#  22  replies            188 non-null    object
#  23  is_locked          188 non-null    float64
#  24  subscribed         188 non-null    float64
#  25  parent_user_id     651 non-null    object
#  26  edited             41 non-null     object
#  27  purpose            3 non-null      object
#  28  x_files            2 non-null      object
#  29  hidden             1 non-null      float64
#  30  bot_id             1 non-null      object
#  31  bot_profile        1 non-null      object
#  32  old_name           1 non-null      object
#  33  name               1 non-null      object
# dtypes: float64(8), object(26)
# memory usage: 352.2+ KB

# %%
# Check if there are any null values in the dataset
slack_df.isna().mean().round(4) * 100
# Out:
# client_msg_id        13.66
# type                  0.00
# text                  0.00
# user                  0.00
# ts                    0.00
# team                 15.99
# user_team            16.07
# source_team          16.07
# user_profile         16.07
# attachments          89.91
# blocks                9.55
# channel_name          0.00
# subtype              94.02
# reactions            75.31
# files                89.98
# upload               89.98
# display_as_bot       91.07
# thread_ts            34.86
# reply_count          85.40
# reply_users_count    85.40
# latest_reply         85.40
# reply_users          85.40
# replies              85.40
# is_locked            85.40
# subscribed           85.40
# parent_user_id       49.46
# edited               96.82
# purpose              99.77
# x_files              99.84
# hidden               99.92
# bot_id               99.92
# bot_profile          99.92
# old_name             99.92
# name                 99.92
# dtype: float64

# %% [markdown]
# #### Note:
#
# The missing values in the dataset do not correspond to missing data, but rather the fact that some posts do not have replies, attachments, or reactions. For the task at hand, what is most important is that the 'text' and 'user' columns do not have missing values.
#
# With these boxes checked, we can bgein a deeper dive into assesment of the rows to identitfy what we don't need.

# %%
# Count the values of the 'subtype' column
slack_df['subtype'].value_counts()
# Out:
# channel_join       72
# channel_purpose     3
# tombstone           1
# channel_name        1
# Name: subtype, dtype: int64

# %% [markdown]
# ### Summary of Data Assessment
#
# #### Columns to drop:
#
# - type, team, user_team, source_team, latest_reply, last_read, bot_id, bot_profile, display_as_bot, topic, blocks, edited, is_locked, subscribed, upload, display_as_bot, root, purpose, thread_ts, parent_used_id
#
# #### Columns to clean & wrangle:
#
# - subtype: filter out it's values from df, remove the original column
# - ts: changing it to datetime, remove miliseconds, get days of the week, months of the year, type of the day, parts of the day
# - user_profile: extract real_name in new column, remove the original
# - attachments: extract title, text, link in new columns
# - files: extract url_private and who shared
# - attachments: extract title, text, link in new columns
# - reactions: extract user, count, name of the emoji

# %% [markdown]
# ### Preparing for Cleaning

# %%
# Make a copy of the DataFrame for the cleaning process
slack_df_clean = slack_df.copy()

# %%
# Review the DateFrame
slack_df_clean.head()
# Out:
#                           client_msg_id     type  \
# 0  5bf56972-c421-4d08-8f14-1af9a35e67eb  message
# 1  2f74859f-3d4b-4b0b-a666-aaa289787dae  message
# 0                                   NaN  message
# 1                                   NaN  message
# 2                                   NaN  message
#
#                                                 text         user  \
# 0  two upcoming conferences:\n• finovatefall sept...  U023R27V74N
# 1  also two free virtual expos sept 29-30:\n• blo...  U023R27V74N
# 0              <@U023TR6SGJZ> has joined the channel  U023TR6SGJZ
# 1              <@U023QT9923G> has joined the channel  U023QT9923G
# 2              <@U023R27V74N> has joined the channel  U023R27V74N
#
#              ts         team    user_team  source_team  \
# 0  1.628731e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 1  1.628733e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.622723e+09          NaN          NaN          NaN
# 1  1.622733e+09          NaN          NaN          NaN
# 2  1.622735e+09          NaN          NaN          NaN
#
#                                         user_profile  \
# 0  {'avatar_hash': '425d563aaa26', 'image_72': 'h...
# 1  {'avatar_hash': '425d563aaa26', 'image_72': 'h...
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#                                          attachments  ... subscribed  \
# 0  [{'title': 'FinovateFall fintech event', 'titl...  ...        NaN
# 1  [{'service_name': 'Blockchain Expo North Ameri...  ...        NaN
# 0                                                NaN  ...        NaN
# 1                                                NaN  ...        NaN
# 2                                                NaN  ...        NaN
#
#   parent_user_id edited purpose x_files hidden bot_id  bot_profile  old_name  \
# 0            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
# 1            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
# 0            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
# 1            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
# 2            NaN    NaN     NaN     NaN    NaN    NaN          NaN       NaN
#
#    name
# 0   NaN
# 1   NaN
# 0   NaN
# 1   NaN
# 2   NaN
#
# [5 rows x 34 columns]

# %%
# Review the column names
slack_df_clean.columns
# Out:
# Index(['client_msg_id', 'type', 'text', 'user', 'ts', 'team', 'user_team',
#        'source_team', 'user_profile', 'attachments', 'blocks', 'channel_name',
#        'subtype', 'reactions', 'files', 'upload', 'display_as_bot',
#        'thread_ts', 'reply_count', 'reply_users_count', 'latest_reply',
#        'reply_users', 'replies', 'is_locked', 'subscribed', 'parent_user_id',
#        'edited', 'purpose', 'x_files', 'hidden', 'bot_id', 'bot_profile',
#        'old_name', 'name'],
#       dtype='object')

# %% [markdown]
# ### Cleaning the Data

# %%
# Creating a cleaning function
def clean_dataframe(slack_df_clean):
    
    # Drop the columns that aren't needed
    slack_df_clean.drop(['type', 'client_msg_id', 'team', 'user_team',
             'source_team', 'blocks', 'upload', 'display_as_bot',
             'thread_ts', 'latest_reply', 'is_locked', 'subscribed',
             'parent_user_id', 'bot_id', 'bot_profile', 'edited',
             'purpose', 'old_name', 'name', 'hidden',
             'x_files'], axis=1, inplace=True)
    
    # Filter for the rows that have subtype values
    slack_df_clean = slack_df_clean[(slack_df_clean.subtype != 'channel_join') &
                                    (slack_df_clean.subtype != 'channel_purpose') &
                                    (slack_df_clean.subtype != 'thread_broadcast')
                                   ]
    
    # Drop subtype column witht the valus we don't need anymore
    slack_df_clean.drop('subtype', axis=1, inplace=True)
    
    return slack_df_clean

# %% [markdown]
# ### Wrangling the Data

# %%
# Create a function to summarise the wranglign steps with datetime
def datetime_wrangling(slack_df_clean):
    
    # Convert ts to datetime from float
    slack_df_clean['ts'] = pd.to_datetime(slack_df_clean['ts'], unit='s').astype('datetime64[s]')
    
    # Create a column for the days of the week using the ts column
    slack_df_clean['day_name'] = slack_df_clean['ts'].dt.day_name()
    slack_df_clean['day_number'] = pd.DatetimeIndex(slack_df_clean['ts']).day
    
    # Create a column for the months of the year using the ts column
    slack_df_clean['month'] = pd.DatetimeIndex(slack_df_clean['ts']).month
    
    # Convert values to date time and the month names
    slack_df_clean['month'] = pd.to_datetime(slack_df_clean['month'], format='%m').dt.month_name()
    
    # Create a column for the type fo the weekday using the ts column
    slack_df_clean['day_type'] = slack_df_clean.ts.dt.weekday.apply(
    lambda x: 'Weekday' if x<5 else 'Weekend')
    
    # Create a column for the hour of the day using the ts column
    slack_df_clean['time'] = slack_df_clean['ts'].dt.strftime('%H')
    
    # Create a column for the parts of the day
    slack_df_clean['dayparts'] = (slack_df_clean['ts'].dt.hour % 24 + 4) // 4
    slack_df_clean['dayparts'].replace({1: 'Late Night',
                                       2: 'Early Morning',
                                       3: 'Morning',
                                       4: 'Afternoon',
                                       5: 'Evening',
                                       6: 'Night'}, inplace=True)
    
    # Drop the ts column
    slack_df_clean.drop('ts', axis=1, inplace=True)
    
    return slack_df_clean

# %%
# Create a function to extract links from columns
def return_attachments(txt):
    try:
        dictionary = (txt)[0]
        if 'original_url' in dictionary:
            return dictionary.get('original_url', 'None')
    except:
        return 'None'
        
slack_df_clean['attachments'] = slack_df_clean['attachments'].apply(return_attachments)

# slack_df_clean.to_csv('slack_attachments.csv', columns=header, index=False)

# %%
# Create function to extract real_name from user_profile
#def real_name(x):
    #if x != x:
        #return 'noname'
    #else:
        #return x['real_name']
    
#slack_df_clean['real_name'] = slack_df_clean['user_profile'].apply(real_name)

# Drop the user_profile column
slack_df_clean.drop('user_profile', axis=1, inplace=True)

# %%
# Create a function to count reactions in columns
def reactions_count(txt):
    reactions_count = 0
    #try:
    #print(txt)
    if str(txt) != "nan":
        #print("is nan")
        #dictionary = eval(txt)[0]
        reactions_count = txt[0].get('count')
        #print(reactions_count)

    #else:
        #print("is not nan")
    #dictionary = eval(txt)[2]
        #if 'reactions' in dictionary:
    #print(dictionary)
            #return dictionary.get('reactions', 'None')
    #return dictionary.get('count')
    #except:
        #return 'None'
    #reactions_count = dictionary.get('count')
    
    #slack_df_clean['reactions_count'] = slack_df_clean['reactions'].apply(reactions_count)
    
    return reactions_count
    
slack_df_clean['reactions_count'] = slack_df_clean['reactions'].apply(reactions_count)

# %%
# Create a function to indicate the name of the emoji related to the reactions
def reactions_name(txt):
    reactions_name = 0
    #print(txt)
    if str(txt) != "nan":
        reactions_name = txt[0].get('name')
        #print(reactions_name)
    return reactions_name

slack_df_clean['reactions_name'] = slack_df_clean['reactions'].apply(reactions_name)

# %%
# Create a function to indicate the user ID related to the reactions (and name)

def reactions_user(txt):
    reactions_user = 0
    #print(txt)
    if str(txt) != "nan":
        reactions_user = txt[0].get('users')
        #print(reactions_user)
    return reactions_user

slack_df_clean['reactions_user'] = slack_df_clean['reactions'].apply(reactions_user)

# %%
# Review the new columns in the dataframe
slack_df_clean.head(20)
# Out:
#                           client_msg_id     type  \
# 0  5bf56972-c421-4d08-8f14-1af9a35e67eb  message
# 1  2f74859f-3d4b-4b0b-a666-aaa289787dae  message
# 0                                   NaN  message
# 1                                   NaN  message
# 2                                   NaN  message
# 0  0affe36c-6e47-411d-a2f9-2c8be07d0820  message
# 0  DA2A9773-68A6-4B42-B1F5-0AB1C0606CDE  message
# 0  7FE32927-8069-448D-B5B1-A9FB66082AFD  message
# 0  fb703761-514c-4e85-a41c-81c8306a145b  message
# 0  cf458988-7dac-47c6-9782-c798a4775ab1  message
# 0  31e1fdad-9973-4d0e-9e03-422f2c572705  message
# 0                                   NaN  message
# 1                                   NaN  message
# 0                                   NaN  message
# 0  3ff77c90-3078-479e-bc29-a937039ffa74  message
# 0                                   NaN  message
# 1                                   NaN  message
# 2                                   NaN  message
# 3                                   NaN  message
# 0                                   NaN  message
#
#                                                 text         user  \
# 0  two upcoming conferences:\n• finovatefall sept...  U023R27V74N
# 1  also two free virtual expos sept 29-30:\n• blo...  U023R27V74N
# 0              <@U023TR6SGJZ> has joined the channel  U023TR6SGJZ
# 1              <@U023QT9923G> has joined the channel  U023QT9923G
# 2              <@U023R27V74N> has joined the channel  U023R27V74N
# 0  the columbia center of ai is having a symposiu...  U023R27V74N
# 0  Y’all, free diy NFT class kicking off at 12pm ...  U025DPVSGBT
# 0  Anyone interested in next generation APIs here...  U024R294XHV
# 0  <https://medium.com/derivadex/what-are-perpetu...  U025DPVSGBT
# 0  <https://www.fastcompany.com/90669744/spotify-...  U023R27V74N
# 0  if you are interested in learning how azure su...  U023R27V74N
# 0              <@U023MQ9J9P0> has joined the channel  U023MQ9J9P0
# 1              <@U023F2P1CKZ> has joined the channel  U023F2P1CKZ
# 0  Fintech Junction Summer Event\nThere is a free...  U023R27V74N
# 0  MoneyNext Open Banking Summit June 22-23\nIf y...  U023R27V74N
# 0              <@U024GNF18MB> has joined the channel  U024GNF18MB
# 1              <@U024GNX9CGM> has joined the channel  U024GNX9CGM
# 2              <@U0259QYTM1N> has joined the channel  U0259QYTM1N
# 3              <@U024YNXFLUR> has joined the channel  U024YNXFLUR
# 0  Been following this company for a bit of a whi...  U024R294XHV
#
#              ts         team    user_team  source_team  \
# 0  1.628731e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 1  1.628733e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.622723e+09          NaN          NaN          NaN
# 1  1.622733e+09          NaN          NaN          NaN
# 2  1.622735e+09          NaN          NaN          NaN
# 0  1.633027e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.632670e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.633523e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.633617e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.630342e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.633992e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.622667e+09          NaN          NaN          NaN
# 1  1.622703e+09          NaN          NaN          NaN
# 0  1.624379e+09          NaN          NaN          NaN
# 0  1.624044e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
# 0  1.623280e+09          NaN          NaN          NaN
# 1  1.623281e+09          NaN          NaN          NaN
# 2  1.623286e+09          NaN          NaN          NaN
# 3  1.623290e+09          NaN          NaN          NaN
# 0  1.634837e+09  T024JBZ7VTJ  T024JBZ7VTJ  T024JBZ7VTJ
#
#                                          attachments  \
# 0           https://informaconnect.com/finovatefall/
# 1          https://blockchain-expo.com/northamerica/
# 0                                               None
# 1                                               None
# 2                                               None
# 0  https://www.eventbrite.com/e/cait-inaugural-sy...
# 0                   https://buildspace.so/build-nfts
# 0              https://www.sigtech.com/platform/data
# 0  https://medium.com/derivadex/what-are-perpetua...
# 0  https://www.fastcompany.com/90669744/spotify-t...
# 0  https://info.microsoft.com/ww-landing-use-ai-t...
# 0                                               None
# 1                                               None
# 0                                               None
# 0          https://moneynext.tv/open-banking-summit/
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 0  https://quantum-stellar.io/Stellar%20-%20About...
#
#                                               blocks  ... purpose x_files  \
# 0  [{'type': 'rich_text', 'block_id': 'XF1K', 'el...  ...     NaN     NaN
# 1  [{'type': 'rich_text', 'block_id': 'FK8', 'ele...  ...     NaN     NaN
# 0                                                NaN  ...     NaN     NaN
# 1                                                NaN  ...     NaN     NaN
# 2                                                NaN  ...     NaN     NaN
# 0  [{'type': 'rich_text', 'block_id': '4VM', 'ele...  ...     NaN     NaN
# 0  [{'type': 'rich_text', 'block_id': '63P', 'ele...  ...     NaN     NaN
# 0  [{'type': 'rich_text', 'block_id': 'XbCc', 'el...  ...     NaN     NaN
# 0  [{'type': 'rich_text', 'block_id': '6Rw5', 'el...  ...     NaN     NaN
# 0  [{'type': 'rich_text', 'block_id': 'UriP', 'el...  ...     NaN     NaN
# 0  [{'type': 'rich_text', 'block_id': 'huz', 'ele...  ...     NaN     NaN
# 0                                                NaN  ...     NaN     NaN
# 1                                                NaN  ...     NaN     NaN
# 0  [{'type': 'rich_text', 'block_id': 'kxme', 'el...  ...     NaN     NaN
# 0  [{'type': 'rich_text', 'block_id': 'aabnW', 'e...  ...     NaN     NaN
# 0                                                NaN  ...     NaN     NaN
# 1                                                NaN  ...     NaN     NaN
# 2                                                NaN  ...     NaN     NaN
# 3                                                NaN  ...     NaN     NaN
# 0                                                NaN  ...     NaN     NaN
#
#   hidden bot_id bot_profile old_name  name  reactions_count  reactions_name  \
# 0    NaN    NaN         NaN      NaN   NaN                0               0
# 1    NaN    NaN         NaN      NaN   NaN                0               0
# 0    NaN    NaN         NaN      NaN   NaN                0               0
# 1    NaN    NaN         NaN      NaN   NaN                0               0
# 2    NaN    NaN         NaN      NaN   NaN                0               0
# 0    NaN    NaN         NaN      NaN   NaN                1          muscle
# 0    NaN    NaN         NaN      NaN   NaN                3              +1
# 0    NaN    NaN         NaN      NaN   NaN                2            fire
# 0    NaN    NaN         NaN      NaN   NaN                1    orange_heart
# 0    NaN    NaN         NaN      NaN   NaN                0               0
# 0    NaN    NaN         NaN      NaN   NaN                0               0
# 0    NaN    NaN         NaN      NaN   NaN                0               0
# 1    NaN    NaN         NaN      NaN   NaN                0               0
# 0    NaN    NaN         NaN      NaN   NaN                2              +1
# 0    NaN    NaN         NaN      NaN   NaN                6              +1
# 0    NaN    NaN         NaN      NaN   NaN                0               0
# 1    NaN    NaN         NaN      NaN   NaN                0               0
# 2    NaN    NaN         NaN      NaN   NaN                0               0
# 3    NaN    NaN         NaN      NaN   NaN                0               0
# 0    NaN    NaN         NaN      NaN   NaN                1            eyes
#
#                                       reactions_user
# 0                                                  0
# 1                                                  0
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 0                                      [U025DPVSGBT]
# 0            [U024J6725K8, U025GLTLJBE, U025E9FJVNU]
# 0                         [U025DPVSGBT, U023R27V74N]
# 0                                      [U024GNX9CGM]
# 0                                                  0
# 0                                                  0
# 0                                                  0
# 1                                                  0
# 0                         [U024GNX9CGM, U024WMKUP0C]
# 0  [U024SCVTY5T, U024GNX9CGM, U025DPVSGBT, U02548...
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 0                                      [U023R27V74N]
#
# [20 rows x 36 columns]

# %%
# Create a function to create a new column with boolean features
def boolean_features(slack_df_clean):
    
    # Create a new boolean column if comment has reaction
    #slack_df_clean['reaction_true'] = slack_df_clean['reactions_name'].notna()
    slack_df_clean['reaction_true'] = slack_df_clean['reactions_count'].notna()
    
    # Create a new boolean column if comment has reply
    slack_df_clean['replies_true'] = slack_df_clean['reply_count'].notna()
    
    # Create a new boolean column if the comment has attachments
    slack_df_clean['attachments_true'] = slack_df_clean['attachments'].notna()
    
    return slack_df_clean

# %%
# Create a function to create a new column with text length
def text_length(slack_df_clean):
    slack_df_clean['text_length'] = slack_df_clean['text'].astype(str).map(len)
    
    return slack_df_clean

# %%
# Get info on the cleaned DataFrame
slack_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1288 entries, 0 to 1
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   client_msg_id      1112 non-null   object
#  1   type               1288 non-null   object
#  2   text               1288 non-null   object
#  3   user               1288 non-null   object
#  4   ts                 1288 non-null   float64
#  5   team               1082 non-null   object
#  6   user_team          1081 non-null   object
#  7   source_team        1081 non-null   object
#  8   attachments        1288 non-null   object
#  9   blocks             1165 non-null   object
#  10  channel_name       1288 non-null   object
#  11  subtype            77 non-null     object
#  12  reactions          318 non-null    object
#  13  files              129 non-null    object
#  14  upload             129 non-null    object
#  15  display_as_bot     115 non-null    object
#  16  thread_ts          839 non-null    float64
#  17  reply_count        188 non-null    float64
#  18  reply_users_count  188 non-null    float64
#  19  latest_reply       188 non-null    float64
#  20  reply_users        188 non-null    object
#  21  replies            188 non-null    object
#  22  is_locked          188 non-null    float64
#  23  subscribed         188 non-null    float64
#  24  parent_user_id     651 non-null    object
#  25  edited             41 non-null     object
#  26  purpose            3 non-null      object
#  27  x_files            2 non-null      object
#  28  hidden             1 non-null      float64
#  29  bot_id             1 non-null      object
#  30  bot_profile        1 non-null      object
#  31  old_name           1 non-null      object
#  32  name               1 non-null      object
#  33  reactions_count    1288 non-null   int64
#  34  reactions_name     1288 non-null   object
#  35  reactions_user     1288 non-null   object
# dtypes: float64(8), int64(1), object(27)
# memory usage: 372.3+ KB

# %%
# Call the clean_dataframe function
slack_df_clean = clean_dataframe(slack_df_clean)

# %%
# Call the datetime_wrangling function
slack_df_clean = datetime_wrangling(slack_df_clean)

# %%
# Call the boolean_features function
slack_df_clean = boolean_features(slack_df_clean)

# %%
# Call the text_length function
slack_df_clean = text_length(slack_df_clean)

# %%
# Review the DataFrame
slack_df_clean.head(20)
# Out:
#                                                 text         user  \
# 0  two upcoming conferences:\n• finovatefall sept...  U023R27V74N
# 1  also two free virtual expos sept 29-30:\n• blo...  U023R27V74N
# 0  the columbia center of ai is having a symposiu...  U023R27V74N
# 0  Y’all, free diy NFT class kicking off at 12pm ...  U025DPVSGBT
# 0  Anyone interested in next generation APIs here...  U024R294XHV
# 0  <https://medium.com/derivadex/what-are-perpetu...  U025DPVSGBT
# 0  <https://www.fastcompany.com/90669744/spotify-...  U023R27V74N
# 0  if you are interested in learning how azure su...  U023R27V74N
# 0  Fintech Junction Summer Event\nThere is a free...  U023R27V74N
# 0  MoneyNext Open Banking Summit June 22-23\nIf y...  U023R27V74N
# 0  Been following this company for a bit of a whi...  U024R294XHV
# 1  If anyone is interested in joining their teleg...  U024R294XHV
# 2                                   I am interested!  U025DPVSGBT
# 3  Couple of things I want to mention about stell...  U024R294XHV
# 4                              I’ll send you a link   U024R294XHV
# 5  <https://t.me/quantumstellar|https://t.me/quan...  U024R294XHV
# 6  Claims are being made that quantum computing i...  U024R294XHV
# 7  Here’s their mother website <https://www.class...  U024R294XHV
# 8  ETH competitors \n\n<https://ethex-smm.medium....  U024R294XHV
# 0  I could use a Fintech Career Strategist. Anyon...  U025E9FJVNU
#
#                                          attachments channel_name  \
# 0           https://informaconnect.com/finovatefall/      fintech
# 1          https://blockchain-expo.com/northamerica/      fintech
# 0  https://www.eventbrite.com/e/cait-inaugural-sy...      fintech
# 0                   https://buildspace.so/build-nfts      fintech
# 0              https://www.sigtech.com/platform/data      fintech
# 0  https://medium.com/derivadex/what-are-perpetua...      fintech
# 0  https://www.fastcompany.com/90669744/spotify-t...      fintech
# 0  https://info.microsoft.com/ww-landing-use-ai-t...      fintech
# 0                                               None      fintech
# 0          https://moneynext.tv/open-banking-summit/      fintech
# 0  https://quantum-stellar.io/Stellar%20-%20About...      fintech
# 1                                               None      fintech
# 2                                               None      fintech
# 3                                               None      fintech
# 4                                               None      fintech
# 5                        https://t.me/quantumstellar      fintech
# 6                                               None      fintech
# 7                             https://www.classiq.io      fintech
# 8  https://ethex-smm.medium.com/top-5-altcoins-to...      fintech
# 0                                               None      fintech
#
#                                            reactions  \
# 0                                                NaN
# 1                                                NaN
# 0  [{'name': 'muscle', 'users': ['U025DPVSGBT'], ...
# 0  [{'name': '+1', 'users': ['U024J6725K8', 'U025...
# 0  [{'name': 'fire', 'users': ['U025DPVSGBT', 'U0...
# 0  [{'name': 'orange_heart', 'users': ['U024GNX9C...
# 0                                                NaN
# 0                                                NaN
# 0  [{'name': '+1', 'users': ['U024GNX9CGM', 'U024...
# 0  [{'name': '+1', 'users': ['U024SCVTY5T', 'U024...
# 0  [{'name': 'eyes', 'users': ['U023R27V74N'], 'c...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  [{'name': 'heart', 'users': ['U025DPVSGBT'], '...
# 0  [{'name': 'white_check_mark', 'users': ['U023R...
#
#                                                files  reply_count  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 0                                                NaN          NaN
# 0                                                NaN          NaN
# 0                                                NaN          NaN
# 0                                                NaN          NaN
# 0                                                NaN          NaN
# 0                                                NaN          NaN
# 0  [{'id': 'F025DPWJ4J3', 'created': 1624378869, ...          NaN
# 0                                                NaN          NaN
# 0                                                NaN          7.0
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
# 5                                                NaN          NaN
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8                                                NaN          NaN
# 0                                                NaN          2.0
#
#    reply_users_count                 reply_users  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 0                NaN                         NaN
# 0                NaN                         NaN
# 0                NaN                         NaN
# 0                NaN                         NaN
# 0                NaN                         NaN
# 0                NaN                         NaN
# 0                NaN                         NaN
# 0                NaN                         NaN
# 0                2.0  [U024R294XHV, U025DPVSGBT]
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
# 5                NaN                         NaN
# 6                NaN                         NaN
# 7                NaN                         NaN
# 8                NaN                         NaN
# 0                1.0               [U023R27V74N]
#
#                                              replies  ...   day_name  \
# 0                                                NaN  ...   Thursday
# 1                                                NaN  ...   Thursday
# 0                                                NaN  ...   Thursday
# 0                                                NaN  ...     Sunday
# 0                                                NaN  ...  Wednesday
# 0                                                NaN  ...   Thursday
# 0                                                NaN  ...     Monday
# 0                                                NaN  ...     Monday
# 0                                                NaN  ...    Tuesday
# 0                                                NaN  ...     Friday
# 0  [{'user': 'U024R294XHV', 'ts': '1634837353.000...  ...   Thursday
# 1                                                NaN  ...   Thursday
# 2                                                NaN  ...   Thursday
# 3                                                NaN  ...   Thursday
# 4                                                NaN  ...   Thursday
# 5                                                NaN  ...   Thursday
# 6                                                NaN  ...   Thursday
# 7                                                NaN  ...   Thursday
# 8                                                NaN  ...   Thursday
# 0  [{'user': 'U023R27V74N', 'ts': '1628127165.000...  ...   Thursday
#
#   day_number      month day_type  time    dayparts reaction_true replies_true  \
# 0         12     August  Weekday    01  Late Night          True        False
# 1         12     August  Weekday    01  Late Night          True        False
# 0         30  September  Weekday    18     Evening          True        False
# 0         26  September  Weekend    15   Afternoon          True        False
# 0          6    October  Weekday    12   Afternoon          True        False
# 0          7    October  Weekday    14   Afternoon          True        False
# 0         30     August  Weekday    16     Evening          True        False
# 0         11    October  Weekday    22       Night          True        False
# 0         22       June  Weekday    16     Evening          True        False
# 0         18       June  Weekday    19     Evening          True        False
# 0         21    October  Weekday    17     Evening          True         True
# 1         21    October  Weekday    17     Evening          True        False
# 2         21    October  Weekday    17     Evening          True        False
# 3         21    October  Weekday    17     Evening          True        False
# 4         21    October  Weekday    17     Evening          True        False
# 5         21    October  Weekday    17     Evening          True        False
# 6         21    October  Weekday    17     Evening          True        False
# 7         21    October  Weekday    17     Evening          True        False
# 8         21    October  Weekday    23       Night          True        False
# 0         29       July  Weekday    16     Evening          True         True
#
#   attachments_true  text_length
# 0             True          415
# 1             True          168
# 0             True          170
# 0             True          120
# 0             True          206
# 0             True          208
# 0             True           66
# 0             True          644
# 0             True          107
# 0             True          159
# 0             True          777
# 1             True           70
# 2             True           16
# 3             True          501
# 4             True           21
# 5             True           57
# 6             True          128
# 7             True           75
# 8             True          229
# 0             True           76
#
# [20 rows x 23 columns]

# %% [markdown]
# ### Feature Engineering and Another Cleaning

# %%
# Create another cleaning function to drop unnecessary columns, replace None values, and reorder columns
def clean_post_feateng(slack_df_clean):
    
    # Drop unnecessary columns
    slack_df_clean.drop(['reactions', 'reply_users', 'replies'], axis=1, inplace=True)
    
    # Replace None values with 0
    slack_df_clean['reply_count'] = slack_df_clean['reply_count'].fillna(0)
    slack_df_clean['reply_users_count'] = slack_df_clean['reply_users_count'].fillna(0)
    slack_df_clean['reply_count'] = slack_df_clean['reply_count'].astype(int)
    slack_df_clean['reply_users_count'] = slack_df_clean['reply_users_count'].astype(int)
    
    # Reorder columns
    slack_df_clean = slack_df_clean[['channel_name', 'user', #'real_name',
                     'text', 'text_length', 'reply_count', 'reply_users_count',
                     'replies_true', 'day_name', 'day_type', 'time',
                     'dayparts', 'day_number', 'month', 'reactions_count', 
                     'reactions_name', 'attachments', 'attachments_true', 'reaction_true']]
    
    return slack_df_clean

# %%
# function call
slack_df_clean = clean_post_feateng(slack_df_clean)

# %%
# Review the cleaned DataFrame post-feature engineering
slack_df_clean.head()
# Out:
#   channel_name         user  \
# 0      fintech  U023R27V74N
# 1      fintech  U023R27V74N
# 0      fintech  U023R27V74N
# 0      fintech  U025DPVSGBT
# 0      fintech  U024R294XHV
#
#                                                 text  text_length  \
# 0  two upcoming conferences:\n• finovatefall sept...          415
# 1  also two free virtual expos sept 29-30:\n• blo...          168
# 0  the columbia center of ai is having a symposiu...          170
# 0  Y’all, free diy NFT class kicking off at 12pm ...          120
# 0  Anyone interested in next generation APIs here...          206
#
#    reply_count  reply_users_count  replies_true   day_name day_type time  \
# 0            0                  0         False   Thursday  Weekday   01
# 1            0                  0         False   Thursday  Weekday   01
# 0            0                  0         False   Thursday  Weekday   18
# 0            0                  0         False     Sunday  Weekend   15
# 0            0                  0         False  Wednesday  Weekday   12
#
#      dayparts  day_number      month  reactions_count reactions_name  \
# 0  Late Night          12     August                0              0
# 1  Late Night          12     August                0              0
# 0     Evening          30  September                1         muscle
# 0   Afternoon          26  September                3             +1
# 0   Afternoon           6    October                2           fire
#
#                                          attachments  attachments_true  \
# 0           https://informaconnect.com/finovatefall/              True
# 1          https://blockchain-expo.com/northamerica/              True
# 0  https://www.eventbrite.com/e/cait-inaugural-sy...              True
# 0                   https://buildspace.so/build-nfts              True
# 0              https://www.sigtech.com/platform/data              True
#
#    reaction_true
# 0           True
# 1           True
# 0           True
# 0           True
# 0           True

# %%
# Save to csv
slack_df_clean.to_csv('slack_cleaned.csv', index=False)
